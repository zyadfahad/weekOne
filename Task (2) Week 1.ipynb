# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
import pandas as pd
df = pd.read_csv('Task (1) Dataset.csv')
df2 = pd.read_csv('Task (2) Dataset.csv')

# %%
df2.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0         0.7                   13           59.611918       54.803617
# 1         1.7                    8           60.221387       56.118629
# 2         2.8                    6           59.161978       55.518834
# 3         5.5                    6           59.738138       56.413917
# 4         6.5                    5           58.958314       56.059246

# %%
column_to_merge = df['Weather_conditions']
df2 = pd.concat([df2,column_to_merge],axis=1)

# %%
df2.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive  \
# 0         0.7                   13           59.611918       54.803617
# 1         1.7                    8           60.221387       56.118629
# 2         2.8                    6           59.161978       55.518834
# 3         5.5                    6           59.738138       56.413917
# 4         6.5                    5           58.958314       56.059246
#
#   Weather_conditions
# 0             Normal
# 1             Normal
# 2             Normal
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
import seaborn as sns
sns.histplot(df2['TrafficIndexLive'], kde=True, bins=20, color='blue')

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
sns.barplot(data=df2, x='TrafficIndexLive', y='Weather_conditions', palette='muted')
# Out:
# C:\Users\zyadf\AppData\Local\Temp\ipykernel_17508\3223398564.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df2, x='TrafficIndexLive', y='Weather_conditions', palette='muted')
# <Axes: xlabel='TrafficIndexLive', ylabel='Weather_conditions'>

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
import matplotlib.pyplot as plt
plt.hist(df2['JamsCount'])
# Out:
# (array([5.5185e+04, 7.2190e+03, 2.7340e+03, 9.9600e+02, 3.7500e+02,
#         1.1100e+02, 1.6000e+01, 0.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([   0. ,  135.9,  271.8,  407.7,  543.6,  679.5,  815.4,  951.3,
#         1087.2, 1223.1, 1359. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(data=df2, x='City', y='TravelTimeLive')
# Out:
# <Axes: xlabel='City', ylabel='TravelTimeLive'>

# %%
sns.barplot(data=df2, x='City', y='TravelTimeHistoric', palette='muted')
# Out:
# C:\Users\zyadf\AppData\Local\Temp\ipykernel_17508\369798728.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df2, x='City', y='TravelTimeHistoric', palette='muted')
# <Axes: xlabel='City', ylabel='TravelTimeHistoric'>

# %%
sns.violinplot(data=df2, x='TravelTimeLive', y='TravelTimeHistoric', split=True)

# %%
plt.hist(df2['TrafficIndexWeekAgo'])
# Out:
# (array([3.9016e+04, 1.7813e+04, 6.8240e+03, 2.0170e+03, 7.4500e+02,
#         1.9100e+02, 2.2000e+01, 8.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  0. ,  13.8,  27.6,  41.4,  55.2,  69. ,  82.8,  96.6, 110.4,
#         124.2, 138. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
we can see that the travel time is signefecant more now then it was historicly
we can see what city have more traffic
